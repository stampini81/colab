# %% [markdown]
# <a href="https://colab.research.google.com/github/stampini81/colab/blob/main/Pandas_Matplotlib_QueryResults.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import os

# O caminho é para a raiz do seu Google Drive
caminho_dos_arquivos = '/content/gdrive/MyDrive/'
os.chdir(caminho_dos_arquivos)

# Verifique se o diretório foi alterado e se os arquivos estão lá
print(os.listdir())
# Out:
# ['photo (1).gdoc', 'photo.gdoc', '1349616055052006.gdoc', 'pozzoli_-_partes_3_e_4_-_compl.gdoc', 'vcards_20170702_161005.vcf', '06-Planilha Controle Leadro.1.docx', 'Escala  Josue  01 a 31 de Outubro     2017 Jaupavi Paulistania (1).docx', 'Escala  Josue  01 a 31 de Outubro     2017 Jaupavi Paulistania.docx', '1510443528925blob.jpg', 'VisualizaTicket (1).pdf', 'VisualizaTicket (2).pdf', 'Imagem (53).jpg', 'Imagem (54).jpg', 'Imagem (55).jpg', 'Imagem (56).jpg', 'Imagem (57).jpg', 'Imagem (58).jpg', 'Imagem (59).jpg', 'Imagem (60).jpg', 'Imagem (61).jpg', 'Imagem (62).jpg', 'Imagem (63).jpg', 'Aviso Prévio Pessoal Marília.rar', 'Epson iPrint', '05- Escala  Jaupavi Polo e Fazenda   01 a 31 de  Maio  2018.docx', '05-PLANILHA CONTROLE LEANDRO. SP 225 MAIO JAUPAVI JAU SP 255.docx.pdf', '01 - Escala Furlaniiii  de  01 a 30 Junho 2017.gdoc', '30 julho', 'Destinos de Viagens', 'Quitanda Frutas.gsheet', 'Segunda via da conta.pdf', 'Glossario.apk', 'ETECMAM - Pesquisa COVID 19.gform', 'Gloss
# ...

# %%
import pandas as pd

df_query_results = pd.read_csv('QueryResults.csv', skiprows=1)

print("Arquivo QueryResults.csv carregado com sucesso!")
print(f"Dimensão de df_query_results: {df_query_results.shape}")
# Out:
# Arquivo QueryResults.csv carregado com sucesso!
# Dimensão de df_query_results: (1990, 3)

# %%
print("Primeiras 5 linhas de df_query_results:")
print(df_query_results.head())
print("\nÚltimas 5 linhas de df_query_results:")
print(df_query_results.tail())
# Out:
# Primeiras 5 linhas de df_query_results:
#    2008-07-01 00:00:00          c#    3
# 0  2008-08-01 00:00:00    assembly    8
# 1  2008-08-01 00:00:00  javascript  162
# 2  2008-08-01 00:00:00           c   85
# 3  2008-08-01 00:00:00      python  124
# 4  2008-08-01 00:00:00        perl   28
#
# Últimas 5 linhas de df_query_results:
#       2008-07-01 00:00:00     c#     3
# 1985  2020-07-01 00:00:00      r  5694
# 1986  2020-07-01 00:00:00     go   743
# 1987  2020-07-01 00:00:00   ruby   775
# 1988  2020-07-01 00:00:00   perl   182
# 1989  2020-07-01 00:00:00  swift  3607

# %%
print("\nDimensão de df_query_results:")
print(df_query_results.shape)
# Out:
# Dimensão de df_query_results:
# (1990, 3)

# %%
print("\nInformações de df_query_results:")
df_query_results.info()
# Out:
# Informações de df_query_results:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1990 entries, 0 to 1989
# Data columns (total 3 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   2008-07-01 00:00:00  1990 non-null   object
#  1   c#                   1990 non-null   object
#  2   3                    1990 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 46.8+ KB

# %%
print("Primeiras 10 linhas de df_query_results:")
print(df_query_results.head(10))
# Out:
# Primeiras 10 linhas de df_query_results:
#    2008-07-01 00:00:00          c#    3
# 0  2008-08-01 00:00:00    assembly    8
# 1  2008-08-01 00:00:00  javascript  162
# 2  2008-08-01 00:00:00           c   85
# 3  2008-08-01 00:00:00      python  124
# 4  2008-08-01 00:00:00        perl   28
# 5  2008-08-01 00:00:00          c#  511
# 6  2008-08-01 00:00:00         c++  164
# 7  2008-08-01 00:00:00        java  222
# 8  2008-08-01 00:00:00      delphi   14
# 9  2008-08-01 00:00:00        ruby   73

# %%
# Recarrega o CSV, indicando que não há cabeçalho
df_query_results = pd.read_csv('QueryResults.csv', header=None)

# %%
print("Primeiras 5 linhas após recarregar sem cabeçalho:")
print(df_query_results.head())
# Out:
# Primeiras 5 linhas após recarregar sem cabeçalho:
#                      0           1      2
# 0                    m     TagName    NaN
# 1  2008-07-01 00:00:00          c#    3.0
# 2  2008-08-01 00:00:00    assembly    8.0
# 3  2008-08-01 00:00:00  javascript  162.0
# 4  2008-08-01 00:00:00           c   85.0

# %%
# Renomeia as colunas
df_query_results.columns = ['mdate', 'tag', 'posts']

# %%
# Recarrega o CSV, indicando que a primeira linha (índice 0) é o cabeçalho
df_query_results = pd.read_csv('QueryResults.csv', header=0)

# %%
print("Primeiras 5 linhas após recarregar com header=0:")
print(df_query_results.head())
# Out:
# Primeiras 5 linhas após recarregar com header=0:
#                      m     TagName  Unnamed: 2
# 0  2008-07-01 00:00:00          c#           3
# 1  2008-08-01 00:00:00    assembly           8
# 2  2008-08-01 00:00:00  javascript         162
# 3  2008-08-01 00:00:00           c          85
# 4  2008-08-01 00:00:00      python         124

# %%
# Renomeia as colunas para algo mais significativo
df_query_results.columns = ['mdate', 'tag', 'posts']

# %%
print("\nPrimeiras 5 linhas após renomear colunas:")
print(df_query_results.head())
print("\nInformações de df_query_results após renomear:")
df_query_results.info()
# Out:
# Primeiras 5 linhas após renomear colunas:
#                  mdate         tag  posts
# 0  2008-07-01 00:00:00          c#      3
# 1  2008-08-01 00:00:00    assembly      8
# 2  2008-08-01 00:00:00  javascript    162
# 3  2008-08-01 00:00:00           c     85
# 4  2008-08-01 00:00:00      python    124
#
# Informações de df_query_results após renomear:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mdate   1991 non-null   object
#  1   tag     1991 non-null   object
#  2   posts   1991 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 46.8+ KB

# %%
df_query_results['mdate'] = pd.to_datetime(df_query_results['mdate'])

# %%
# 1. Converta a coluna 'mdate' para datetime:
df_query_results['mdate'] = pd.to_datetime(df_query_results['mdate'])

# 2. Verifique as informações do DataFrame novamente para confirmar a conversão:
print("Informações de df_query_results após a tentativa de conversão de 'mdate':")
df_query_results.info()
# Out:
# Informações de df_query_results após a tentativa de conversão de 'mdate':
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1991 entries, 0 to 1990
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   mdate   1991 non-null   datetime64[ns]
#  1   tag     1991 non-null   object
#  2   posts   1991 non-null   int64
# dtypes: datetime64[ns](1), int64(1), object(1)
# memory usage: 46.8+ KB

# %%
df_query_results.set_index('mdate', inplace=True)

# %%
reshaped_df = df_query_results.pivot_table(index='mdate', columns='tag', values='posts')

# %%
reshaped_df.head()
# Out:
# tag         assembly      c      c#    c++  delphi  go    java  javascript  \
# mdate
# 2008-07-01       NaN    NaN     3.0    NaN     NaN NaN     NaN         NaN
# 2008-08-01       8.0   85.0   511.0  164.0    14.0 NaN   222.0       162.0
# 2008-09-01      28.0  321.0  1649.0  755.0   105.0 NaN  1137.0       640.0
# 2008-10-01      15.0  303.0  1989.0  811.0   112.0 NaN  1153.0       725.0
# 2008-11-01      17.0  259.0  1730.0  735.0   141.0 NaN   958.0       579.0
#
# tag          perl    php  python    r   ruby  swift
# mdate
# 2008-07-01    NaN    NaN     NaN  NaN    NaN    NaN
# 2008-08-01   28.0  161.0   124.0  NaN   73.0    NaN
# 2008-09-01  131.0  482.0   542.0  6.0  290.0    NaN
# 2008-10-01  127.0  617.0   510.0  NaN  249.0    NaN
# 2008-11-01   97.0  504.0   452.0  1.0  160.0    NaN

# %%
eshaped_df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-1157313461> in <cell line: 0>()
# ----> 1 eshaped_df.info()
#
# NameError: name 'eshaped_df' is not defined

# %%
reshaped_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 145 entries, 2008-07-01 to 2020-07-01
# Data columns (total 14 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   assembly    144 non-null    float64
#  1   c           144 non-null    float64
#  2   c#          145 non-null    float64
#  3   c++         144 non-null    float64
#  4   delphi      144 non-null    float64
#  5   go          129 non-null    float64
#  6   java        144 non-null    float64
#  7   javascript  144 non-null    float64
#  8   perl        144 non-null    float64
#  9   php         144 non-null    float64
#  10  python      144 non-null    float64
#  11  r           142 non-null    float64
#  12  ruby        144 non-null    float64
#  13  swift       135 non-null    float64
# dtypes: float64(14)
# memory usage: 17.0 KB

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(16, 10)) # Define o tamanho do gráfico para melhor visualização
plt.xticks(fontsize=14)     # Aumenta o tamanho da fonte dos rótulos do eixo X
plt.yticks(fontsize=14)     # Aumenta o tamanho da fonte dos rótulos do eixo Y

plt.xlabel('Data', fontsize=14)
plt.ylabel('Número de Posts', fontsize=14)
plt.title('Tendência do Número de Posts por Linguagem de Programação', fontsize=16)

# Plota cada coluna como uma linha separada
plt.plot(reshaped_df.index, reshaped_df.values, linewidth=3)
plt.legend(reshaped_df.columns, fontsize=12) # Adiciona uma legenda com os nomes das colunas (tags)

plt.show()
